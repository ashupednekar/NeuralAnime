# %% [markdown]
# <a href="https://colab.research.google.com/github/ashupednekar/NeuralAnime/blob/master/dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Grayscale every frame and create dataset as seq2seq vectors through VGG19... frame1 -> frame2
#train simple 'shakesphere example' LSTM on this dataset.. try to predict next frames
